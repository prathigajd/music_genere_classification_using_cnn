# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\prathiga jd\anaconda3\lib\site-packages (2.12.0)
# Requirement already satisfied: tensorflow-intel==2.12.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\prathiga jd\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.3.3)
# Requirement already satisfied: setuptools in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (65.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.22.3)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.4.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: packaging in c:\users\prathiga jd\appdata\roaming\python\python310\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.7.0)
# Requirement already satisfied: jax>=0.3.15 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: keras<2.13,>=2.12.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.0.3 in c:\users\prathiga jd\anaconda3\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in c:\users\prathiga jd\appdata\roaming\python\python310\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.17.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\prathiga jd\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\prathiga jd\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\prathiga jd\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\prathiga jd\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prathiga jd\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prathiga jd\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\prathiga jd\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\prathiga jd\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\prathiga jd\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np 
import pandas as pd


import os
for dirname, _, filenames in os.walk('input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import matplotlib.pyplot as plt
import scipy
import librosa
import librosa.display
import IPython.display as ipd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow import keras
import pickle

# %% [markdown]
# # Loading Datasets

# %%
dataf = pd.read_csv("C:/Users/Prathiga Jd/Downloads/Music-Genre-Classification/Music-Genre-Classification/Data/features_3_sec.csv")
dataf.head()
# Out:
#             filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 0  blues.00000.0.wav   66149          0.335406         0.091048  0.130405
# 1  blues.00000.1.wav   66149          0.343065         0.086147  0.112699
# 2  blues.00000.2.wav   66149          0.346815         0.092243  0.132003
# 3  blues.00000.3.wav   66149          0.363639         0.086856  0.132565
# 4  blues.00000.4.wav   66149          0.335579         0.088129  0.143289
#
#     rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 0  0.003521             1773.065032          167541.630869
# 1  0.001450             1816.693777           90525.690866
# 2  0.004620             1788.539719          111407.437613
# 3  0.002448             1655.289045          111952.284517
# 4  0.001701             1630.656199           79667.267654
#
#    spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 0              1972.744388           117335.771563  ...   39.687145
# 1              2010.051501            65671.875673  ...   64.748276
# 2              2084.565132            75124.921716  ...   67.336563
# 3              1960.039988            82913.639269  ...   47.739452
# 4              1948.503884            60204.020268  ...   30.336359
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -3.241280   36.488243     0.722209   38.099152    -5.050335   33.618073
# 1    -6.055294   40.677654     0.159015   51.264091    -2.837699   97.030830
# 2    -1.768610   28.348579     2.378768   45.717648    -1.938424   53.050835
# 3    -3.841155   28.337118     1.218588   34.770935    -3.580352   50.836224
# 4     0.664582   45.880913     1.689446   51.363583    -3.392489   26.738789
#
#    mfcc20_mean  mfcc20_var  label
# 0    -0.243027   43.771767  blues
# 1     5.784063   59.943081  blues
# 2     2.517375   33.105122  blues
# 3     3.630866   32.023678  blues
# 4     0.536961   29.146694  blues
#
# [5 rows x 60 columns]

# %%
dataf.tail()
# Out:
#               filename  length  chroma_stft_mean  chroma_stft_var  rms_mean  \
# 9985  rock.00099.5.wav   66149          0.349126         0.080515  0.050019
# 9986  rock.00099.6.wav   66149          0.372564         0.082626  0.057897
# 9987  rock.00099.7.wav   66149          0.347481         0.089019  0.052403
# 9988  rock.00099.8.wav   66149          0.387527         0.084815  0.066430
# 9989  rock.00099.9.wav   66149          0.369293         0.086759  0.050524
#
#        rms_var  spectral_centroid_mean  spectral_centroid_var  \
# 9985  0.000097             1499.083005          164266.886443
# 9986  0.000088             1847.965128          281054.935973
# 9987  0.000701             1346.157659          662956.246325
# 9988  0.000320             2084.515327          203891.039161
# 9989  0.000067             1634.330126          411429.169769
#
#       spectral_bandwidth_mean  spectral_bandwidth_var  ...  mfcc16_var  \
# 9985              1718.707215            85931.574523  ...   42.485981
# 9986              1906.468492            99727.037054  ...   32.415203
# 9987              1561.859087           138762.841945  ...   78.228149
# 9988              2018.366254            22860.992562  ...   28.323744
# 9989              1867.422378           119722.211518  ...   38.801735
#
#       mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 9985    -9.094270   38.326839    -4.246976   31.049839    -5.625813
# 9986   -12.375726   66.418587    -3.081278   54.414265   -11.960546
# 9987    -2.524483   21.778994     4.809936   25.980829     1.775686
# 9988    -5.363541   17.209942     6.462601   21.442928     2.354765
# 9989   -11.598399   58.983097    -0.178517   55.761299    -6.903252
#
#       mfcc19_var  mfcc20_mean  mfcc20_var  label
# 9985   48.804092     1.818823   38.966969   rock
# 9986   63.452255     0.428857   18.697033   rock
# 9987   48.582378    -0.299545   41.586990   rock
# 9988   24.843613     0.675824   12.787750   rock
# 9989   39.485901    -3.412534   31.727489   rock
#
# [5 rows x 60 columns]

# %%
dataf.shape
# Out:
# (9990, 60)

# %%
dataf.describe()
# Out:
#         length  chroma_stft_mean  chroma_stft_var     rms_mean       rms_var  \
# count   9990.0       9990.000000      9990.000000  9990.000000  9.990000e+03
# mean   66149.0          0.379534         0.084876     0.130859  2.676388e-03
# std        0.0          0.090466         0.009637     0.068545  3.585628e-03
# min    66149.0          0.107108         0.015345     0.000953  4.379535e-08
# 25%    66149.0          0.315698         0.079833     0.083782  6.145900e-04
# 50%    66149.0          0.384741         0.085108     0.121253  1.491318e-03
# 75%    66149.0          0.442443         0.091092     0.176328  3.130862e-03
# max    66149.0          0.749481         0.120964     0.442567  3.261522e-02
#
#        spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# count             9990.000000           9.990000e+03              9990.000000
# mean              2199.219431           4.166727e+05              2241.385959
# std                751.860611           4.349644e+05               543.854449
# min                472.741636           8.118813e+02               499.162910
# 25%               1630.680158           1.231961e+05              1887.455790
# 50%               2208.628236           2.650692e+05              2230.575595
# 75%               2712.581884           5.624152e+05              2588.340505
# max               5432.534406           4.794119e+06              3708.147554
#
#        spectral_bandwidth_var  rolloff_mean  ...  mfcc16_mean   mfcc16_var  \
# count            9.990000e+03   9990.000000  ...  9990.000000  9990.000000
# mean             1.182711e+05   4566.076592  ...     1.448240    49.988755
# std              1.013505e+05   1642.065335  ...     5.735149    34.442816
# min              1.183520e+03    658.336276  ...   -26.850016     1.325786
# 25%              4.876553e+04   3378.311110  ...    -2.227478    29.584894
# 50%              8.996072e+04   4631.377892  ...     1.461623    41.702393
# 75%              1.585674e+05   5591.634521  ...     5.149752    59.274619
# max              1.235143e+06   9487.446477  ...    39.144405   683.932556
#
#        mfcc17_mean   mfcc17_var  mfcc18_mean   mfcc18_var  mfcc19_mean  \
# count  9990.000000  9990.000000  9990.000000  9990.000000  9990.000000
# mean     -4.198706    51.962753     0.739943    52.488851    -2.497306
# std       5.677379    36.400669     5.181313    38.177120     5.111799
# min     -27.809795     1.624544   -20.733809     3.437439   -27.448456
# 25%      -7.951722    29.863448    -2.516638    29.636197    -5.734123
# 50%      -4.443021    42.393583     0.733772    41.831377    -2.702366
# 75%      -0.726945    61.676964     3.888734    62.033906     0.514246
# max      34.048843   529.363342    36.970322   629.729797    31.365425
#
#         mfcc19_var  mfcc20_mean   mfcc20_var
# count  9990.000000  9990.000000  9990.000000
# mean     54.973829    -0.917584    57.322614
# std      41.585677     5.253243    46.444212
# min       3.065302   -35.640659     0.282131
# 25%      30.496412    -4.004475    30.011365
# 50%      43.435253    -1.030939    44.332155
# 75%      65.328602     2.216603    68.210421
# max    1143.230591    34.212101   910.473206
#
# [8 rows x 58 columns]

# %%
dataf = dataf.drop(labels='filename',axis=1)

# %%
 
sample_audio = "C:/Users/Prathiga Jd/Downloads/Music-Genre-Classification/Music-Genre-Classification/Data/genres_original/pop/pop.00003.wav"
sample, sample_rate = librosa.load(sample_audio)


ipd.Audio(sample, rate=sample_rate)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample, sample_rate = librosa.load(sample_audio, sr=16000)
print(len(sample),sample_rate)
# Out:
# 480003 16000

# %%
print(type(sample),sample_rate)
sample, sample_rate = librosa.load(sample_audio, sr=16000)

fig = plt.figure(figsize=(14,6))
ax1 = fig.add_subplot(211)
ax1.set_title("C:/Users/Prathiga Jd/Downloads/Music-Genre-Classification/Music-Genre-Classification/Data/genres_original/pop/pop.00003.wav")
ax1.set_xlabel('time')
ax1.set_ylabel('Amptitude')
librosa.display.waveshow(sample)
plt.show()
# Out:
# <class 'numpy.ndarray'> 16000

# %%
stft = librosa.stft(sample)
stft_db = librosa.amplitude_to_db(abs(stft))
plt.figure(figsize=(14,6))
librosa.display.specshow(stft,sr=sample_rate,x_axis='time',y_axis='hz')
plt.colorbar()
# Out:
# C:\Users\Prathiga Jd\AppData\Local\Temp\ipykernel_25108\130100704.py:4: UserWarning: Trying to display complex-valued input. Showing magnitude instead.
#   librosa.display.specshow(stft,sr=sample_rate,x_axis='time',y_axis='hz')

# %%
stft = librosa.stft(sample)
stft_db = librosa.amplitude_to_db(abs(stft))
plt.figure(figsize=(14,6))
librosa.display.specshow(stft_db,sr=sample_rate,x_axis='time',y_axis='hz')
plt.colorbar()

# %%
# Zero crossing 
plt.figure(figsize=(14,6))
plt.plot(sample[8000:12000])
plt.grid()

# %%
#count
zero_cross = librosa.zero_crossings(sample[8000:12000],pad=False)
print("Count {}".format(sum(zero_cross)))
# Out:
# Count 495

# %% [markdown]
# # Feature Extraction

# %%
class_list = dataf.iloc[:,-1] 
convert = LabelEncoder()

# %%
y = convert.fit_transform(class_list)
y
# Out:
# array([0, 0, 0, ..., 9, 9, 9])

# %%
dataf.iloc[:,:-1]
# Out:
#       length  chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0      66149          0.335406         0.091048  0.130405  0.003521
# 1      66149          0.343065         0.086147  0.112699  0.001450
# 2      66149          0.346815         0.092243  0.132003  0.004620
# 3      66149          0.363639         0.086856  0.132565  0.002448
# 4      66149          0.335579         0.088129  0.143289  0.001701
# ...      ...               ...              ...       ...       ...
# 9985   66149          0.349126         0.080515  0.050019  0.000097
# 9986   66149          0.372564         0.082626  0.057897  0.000088
# 9987   66149          0.347481         0.089019  0.052403  0.000701
# 9988   66149          0.387527         0.084815  0.066430  0.000320
# 9989   66149          0.369293         0.086759  0.050524  0.000067
#
#       spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0                1773.065032          167541.630869              1972.744388
# 1                1816.693777           90525.690866              2010.051501
# 2                1788.539719          111407.437613              2084.565132
# 3                1655.289045          111952.284517              1960.039988
# 4                1630.656199           79667.267654              1948.503884
# ...                      ...                    ...                      ...
# 9985             1499.083005          164266.886443              1718.707215
# 9986             1847.965128          281054.935973              1906.468492
# 9987             1346.157659          662956.246325              1561.859087
# 9988             2084.515327          203891.039161              2018.366254
# 9989             1634.330126          411429.169769              1867.422378
#
#       spectral_bandwidth_var  rolloff_mean  ...  mfcc16_mean  mfcc16_var  \
# 0              117335.771563   3714.560359  ...    -2.853603   39.687145
# 1               65671.875673   3869.682242  ...     4.074709   64.748276
# 2               75124.921716   3997.639160  ...     4.806280   67.336563
# 3               82913.639269   3568.300218  ...    -1.359111   47.739452
# 4               60204.020268   3469.992864  ...     2.092937   30.336359
# ...                      ...           ...  ...          ...         ...
# 9985            85931.574523   3015.559458  ...     5.773784   42.485981
# 9986            99727.037054   3746.694524  ...     2.074155   32.415203
# 9987           138762.841945   2442.362154  ...    -1.005473   78.228149
# 9988            22860.992562   4313.266226  ...     4.123402   28.323744
# 9989           119722.211518   3462.042142  ...     1.342274   38.801735
#
#       mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  \
# 0       -3.241280   36.488243     0.722209   38.099152    -5.050335
# 1       -6.055294   40.677654     0.159015   51.264091    -2.837699
# 2       -1.768610   28.348579     2.378768   45.717648    -1.938424
# 3       -3.841155   28.337118     1.218588   34.770935    -3.580352
# 4        0.664582   45.880913     1.689446   51.363583    -3.392489
# ...           ...         ...          ...         ...          ...
# 9985    -9.094270   38.326839    -4.246976   31.049839    -5.625813
# 9986   -12.375726   66.418587    -3.081278   54.414265   -11.960546
# 9987    -2.524483   21.778994     4.809936   25.980829     1.775686
# 9988    -5.363541   17.209942     6.462601   21.442928     2.354765
# 9989   -11.598399   58.983097    -0.178517   55.761299    -6.903252
#
#       mfcc19_var  mfcc20_mean  mfcc20_var
# 0      33.618073    -0.243027   43.771767
# 1      97.030830     5.784063   59.943081
# 2      53.050835     2.517375   33.105122
# 3      50.836224     3.630866   32.023678
# 4      26.738789     0.536961   29.146694
# ...          ...          ...         ...
# 9985   48.804092     1.818823   38.966969
# 9986   63.452255     0.428857   18.697033
# 9987   48.582378    -0.299545   41.586990
# 9988   24.843613     0.675824   12.787750
# 9989   39.485901    -3.412534   31.727489
#
# [9990 rows x 58 columns]

# %%
# scaling features
from sklearn.preprocessing import StandardScaler
fit = StandardScaler()
X = fit.fit_transform(np.array(dataf.iloc[:,:-1],dtype=float))

# %%
# dividing into training and test Data
X_train,x_test, Y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
print(len(Y_train),len(y_test))
# Out:
# 7992 1998

# %% [markdown]
# # Model Building

# %%
# Using CNN algorithm
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
# building model

model = Sequential()

model.add(Dense(512,input_shape=(X_train.shape[1],),activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(256,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(10,activation='softmax'))


model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               30208
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 203,338
# Trainable params: 203,338
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics='accuracy')

# %%
earlystop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=10,min_delta=0.0001)
modelcheck = ModelCheckpoint('best_model.hdf5',monitor='val_accuracy',verbose=1,save_best_only=True,mode='max')

# %%
history = model.fit(X_train,Y_train, validation_data=(x_test,y_test), epochs=600, callbacks=[earlystop,modelcheck], batch_size=128)
# Out:
# Epoch 1/600
# 60/63 [===========================>..] - ETA: 0s - loss: 1.6301 - accuracy: 0.4143
# Epoch 1: val_accuracy improved from -inf to 0.61862, saving model to best_model.hdf5
# 63/63 [==============================] - 3s 16ms/step - loss: 1.6142 - accuracy: 0.4209 - val_loss: 1.1099 - val_accuracy: 0.6186
# Epoch 2/600
# 60/63 [===========================>..] - ETA: 0s - loss: 1.0962 - accuracy: 0.6159
# Epoch 2: val_accuracy improved from 0.61862 to 0.72823, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 10ms/step - loss: 1.0887 - accuracy: 0.6185 - val_loss: 0.8292 - val_accuracy: 0.7282
# Epoch 3/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.8846 - accuracy: 0.6965
# Epoch 3: val_accuracy improved from 0.72823 to 0.75425, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.8777 - accuracy: 0.6982 - val_loss: 0.7187 - val_accuracy: 0.7543
# Epoch 4/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.7572 - accuracy: 0.7463
# Epoch 4: val_accuracy improved from 0.75425 to 0.79079, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.7590 - accuracy: 0.7452 - val_loss: 0.6445 - val_accuracy: 0.7908
# Epoch 5/600
# 63/63 [==============================] - ETA: 0s - loss: 0.6552 - accuracy: 0.7823
# Epoch 5: val_accuracy improved from 0.79079 to 0.81281, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 11ms/step - loss: 0.6552 - accuracy: 0.7823 - val_loss: 0.5744 - val_accuracy: 0.8128
# Epoch 6/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.5836 - accuracy: 0.8011
# Epoch 6: val_accuracy improved from 0.81281 to 0.82933, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5855 - accuracy: 0.8006 - val_loss: 0.5229 - val_accuracy: 0.8293
# Epoch 7/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.5137 - accuracy: 0.8316
# Epoch 7: val_accuracy improved from 0.82933 to 0.84234, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.5131 - accuracy: 0.8327 - val_loss: 0.4945 - val_accuracy: 0.8423
# Epoch 8/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.4690 - accuracy: 0.8414
# Epoch 8: val_accuracy improved from 0.84234 to 0.84334, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4664 - accuracy: 0.8417 - val_loss: 0.4971 - val_accuracy: 0.8433
# Epoch 9/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.4181 - accuracy: 0.8584
# Epoch 9: val_accuracy improved from 0.84334 to 0.86086, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.4243 - accuracy: 0.8575 - val_loss: 0.4389 - val_accuracy: 0.8609
# Epoch 10/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.3953 - accuracy: 0.8668
# Epoch 10: val_accuracy improved from 0.86086 to 0.86386, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3947 - accuracy: 0.8677 - val_loss: 0.4424 - val_accuracy: 0.8639
# Epoch 11/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.3588 - accuracy: 0.8770
# Epoch 11: val_accuracy improved from 0.86386 to 0.86937, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 9ms/step - loss: 0.3584 - accuracy: 0.8776 - val_loss: 0.4253 - val_accuracy: 0.8694
# Epoch 12/600
# 60/63 [===========================>..] - ETA: 0s - loss: 0.3016 - accuracy: 0.9039
# Epoch 12: val_accuracy improved from 0.86937 to 0.87137, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 10ms/step - loss: 0.3041 - accuracy: 0.9025 - val_loss: 0.4302 - val_accuracy: 0.8714
# Epoch 13/600
# 58/63 [==========================>...] - ETA: 0s - loss: 0.2843 - accuracy: 0.9054
# Epoch 13: val_accuracy improved from 0.87137 to 0.87688, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2908 - accuracy: 0.9033 - val_loss: 0.3957 - val_accuracy: 0.8769
# Epoch 14/600
# 62/63 [============================>.] - ETA: 0s - loss: 0.2674 - accuracy: 0.9122
# Epoch 14: val_accuracy improved from 0.87688 to 0.88939, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2674 - accuracy: 0.9123 - val_loss: 0.3714 - val_accuracy: 0.8894
# Epoch 15/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.2585 - accuracy: 0.9166
# Epoch 15: val_accuracy did not improve from 0.88939
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2570 - accuracy: 0.9168 - val_loss: 0.3954 - val_accuracy: 0.8804
# Epoch 16/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.2387 - accuracy: 0.9202
# Epoch 16: val_accuracy improved from 0.88939 to 0.89139, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2378 - accuracy: 0.9209 - val_loss: 0.3762 - val_accuracy: 0.8914
# Epoch 17/600
# 62/63 [============================>.] - ETA: 0s - loss: 0.2162 - accuracy: 0.9275
# Epoch 17: val_accuracy did not improve from 0.89139
# 63/63 [==============================] - 0s 7ms/step - loss: 0.2156 - accuracy: 0.9277 - val_loss: 0.3755 - val_accuracy: 0.8909
# Epoch 18/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.1952 - accuracy: 0.9357
# Epoch 18: val_accuracy improved from 0.89139 to 0.90140, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 9ms/step - loss: 0.2017 - accuracy: 0.9349 - val_loss: 0.3614 - val_accuracy: 0.9014
# Epoch 19/600
# 62/63 [============================>.] - ETA: 0s - loss: 0.1847 - accuracy: 0.9386
# Epoch 19: val_accuracy did not improve from 0.90140
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1848 - accuracy: 0.9384 - val_loss: 0.3532 - val_accuracy: 0.8934
# Epoch 20/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.1637 - accuracy: 0.9431
# Epoch 20: val_accuracy did not improve from 0.90140
# 63/63 [==============================] - 0s 8ms/step - loss: 0.1654 - accuracy: 0.9427 - val_loss: 0.3662 - val_accuracy: 0.9009
# Epoch 21/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1729 - accuracy: 0.9421
# Epoch 21: val_accuracy did not improve from 0.90140
# 63/63 [==============================] - 0s 8ms/step - loss: 0.1716 - accuracy: 0.9426 - val_loss: 0.3660 - val_accuracy: 0.8964
# Epoch 22/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1474 - accuracy: 0.9534
# Epoch 22: val_accuracy improved from 0.90140 to 0.90440, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 8ms/step - loss: 0.1475 - accuracy: 0.9535 - val_loss: 0.3348 - val_accuracy: 0.9044
# Epoch 23/600
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1359 - accuracy: 0.9585
# Epoch 23: val_accuracy did not improve from 0.90440
# 63/63 [==============================] - 1s 8ms/step - loss: 0.1365 - accuracy: 0.9582 - val_loss: 0.3526 - val_accuracy: 0.9039
# Epoch 24/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.1458 - accuracy: 0.9512
# Epoch 24: val_accuracy did not improve from 0.90440
# 63/63 [==============================] - 0s 8ms/step - loss: 0.1451 - accuracy: 0.9522 - val_loss: 0.3377 - val_accuracy: 0.9034
# Epoch 25/600
# 62/63 [============================>.] - ETA: 0s - loss: 0.1148 - accuracy: 0.9617
# Epoch 25: val_accuracy improved from 0.90440 to 0.90741, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1147 - accuracy: 0.9616 - val_loss: 0.3449 - val_accuracy: 0.9074
# Epoch 26/600
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1297 - accuracy: 0.9554
# Epoch 26: val_accuracy did not improve from 0.90741
# 63/63 [==============================] - 0s 8ms/step - loss: 0.1283 - accuracy: 0.9560 - val_loss: 0.3468 - val_accuracy: 0.9069
# Epoch 27/600
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1172 - accuracy: 0.9644
# Epoch 27: val_accuracy improved from 0.90741 to 0.90791, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1158 - accuracy: 0.9647 - val_loss: 0.3584 - val_accuracy: 0.9079
# Epoch 28/600
# 57/63 [==========================>...] - ETA: 0s - loss: 0.1046 - accuracy: 0.9649
# Epoch 28: val_accuracy did not improve from 0.90791
# 63/63 [==============================] - 0s 8ms/step - loss: 0.1060 - accuracy: 0.9642 - val_loss: 0.3497 - val_accuracy: 0.9074
# Epoch 29/600
# 58/63 [==========================>...] - ETA: 0s - loss: 0.1017 - accuracy: 0.9667
# Epoch 29: val_accuracy improved from 0.90791 to 0.90991, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 9ms/step - loss: 0.1030 - accuracy: 0.9663 - val_loss: 0.3461 - val_accuracy: 0.9099
# Epoch 30/600
# 63/63 [==============================] - ETA: 0s - loss: 0.1059 - accuracy: 0.9650
# Epoch 30: val_accuracy did not improve from 0.90991
# 63/63 [==============================] - 0s 7ms/step - loss: 0.1059 - accuracy: 0.9650 - val_loss: 0.3661 - val_accuracy: 0.9099
# Epoch 31/600
# 59/63 [===========================>..] - ETA: 0s - loss: 0.1030 - accuracy: 0.9664
# Epoch 31: val_accuracy did not improve from 0.90991
# 63/63 [==============================] - 0s 8ms/step - loss: 0.1026 - accuracy: 0.9666 - val_loss: 0.3763 - val_accuracy: 0.9084
# Epoch 32/600
# 61/63 [============================>.] - ETA: 0s - loss: 0.1087 - accuracy: 0.9638
# Epoch 32: val_accuracy improved from 0.90991 to 0.91091, saving model to best_model.hdf5
# 63/63 [==============================] - 1s 8ms/step - loss: 0.1089 - accuracy: 0.9637 - val_loss: 0.3497 - val_accuracy: 0.9109
# Epoch 32: early stopping

# %%
from matplotlib import pyplot 
pyplot.plot(history.history['loss'], label='train') 
pyplot.plot(history.history['val_loss'], label='test') 
pyplot.legend()
pyplot.show()

# %%
test_loss, test_accuracy = model.evaluate(x_test,y_test,batch_size=128)
print("Test loss : ",test_loss)
print("\nBest test accuracy : ",test_accuracy*100)
# Out:
# 16/16 [==============================] - 0s 4ms/step - loss: 0.3497 - accuracy: 0.9109
# Test loss :  0.3497352600097656
#
# Best test accuracy :  91.09109044075012
